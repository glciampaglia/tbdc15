# %%
plt.style.available
# Out:
# [u'dark_background',
#  u'bmh',
#  u'grayscale',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'giovanni']

# %%
# %pylab inline

import matplotlib.pyplot as plt

plt.style.use("giovanni")

plot([1,2,3])
xlabel(r"Hello $\log\left(\alpha\right)$")
ylabel(r"Attention span $\phi +1 / 2$")
# Out:
# Populating the interactive namespace from numpy and matplotlib
